# %%
import os

# %%
# %pwd
# Out:
# 'c:\\Users\\DELL\\Desktop\\Renal-Tumor-Classification-\\Research'

# %%
os.chdir("../")

# %%
# %pwd
# Out:
# 'c:\\Users\\DELL\\Desktop\\Renal-Tumor-Classification-'

# %%
from dataclasses import dataclass
from pathlib import Path


@dataclass(frozen=True)
class DataIngestionConfig:
    root_dir: Path
    source_URL: str
    local_data_file: Path
    unzip_dir: Path

# %%
from cnnClassifier.constants import *

# %%
from cnnClassifier.utils.common import read_yaml, create_directories
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from cnnClassifier.utils.common import read_yaml, create_directories
#
# File c:\users\dell\desktop\renal-tumor-classification-\src\cnnClassifier\utils\common.py:4
#       2 from box.exceptions import BoxValueError
#       3 import yaml
# ----> 4 from cnnClassifier import logger
#       5 import json
#       6 import joblib
#
# ImportError: cannot import name 'logger' from 'cnnClassifier' (c:\users\dell\desktop\renal-tumor-classification-\src\cnnClassifier\__init__.py)
